# %%
import pandas as pd

# %%
data=pd.read_csv('/content/CarPrice_Assignment.csv')

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.drop('car_ID',axis=1,inplace=True)
data.drop('CarName',axis=1,inplace=True)

# %%
data.shape
# Out:
# (205, 24)

# %%
data.describe(include='O')
# Out:
#        fueltype aspiration doornumber carbody drivewheel enginelocation  \
# count       205        205        205     205        205            205
# unique        2          2          2       5          3              2
# top         gas        std       four   sedan        fwd          front
# freq        185        168        115      96        120            202
#
#        enginetype cylindernumber fuelsystem
# count         205            205        205
# unique          7              7          8
# top           ohc           four       mpfi
# freq          148            159         94

# %%
data['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
len(data['CarName'].unique())
# Out:
# 147

# %%
category=data.select_dtypes(include=['object']).columns.tolist()

# %%
category
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
for i in category:
  print(i,data[i].unique())
# Out:
# fueltype ['gas' 'diesel']
# aspiration ['std' 'turbo']
# doornumber ['two' 'four']
# carbody ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drivewheel ['rwd' 'fwd' '4wd']
# enginelocation ['front' 'rear']
# enginetype ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# cylindernumber ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# fuelsystem ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
data=pd.get_dummies(data)

# %%
data.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price',
#        'fueltype_diesel', 'fueltype_gas', 'aspiration_std', 'aspiration_turbo',
#        'doornumber_four', 'doornumber_two', 'carbody_convertible',
#        'carbody_hardtop', 'carbody_hatchback', 'carbody_sedan',
#        'carbody_wagon', 'drivewheel_4wd', 'drivewheel_fwd', 'drivewheel_rwd',
#        'enginelocation_front', 'enginelocation_rear', 'enginetype_dohc',
#        'enginetype_dohcv', 'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf',
#        'enginetype_ohcv', 'enginetype_rotor', 'cylindernumber_eight',
#        'cylindernumber_five', 'cylindernumber_four', 'cylindernumber_six',
#        'cylindernumber_three', 'cylindernumber_twelve', 'cylindernumber_two',
#        'fuelsystem_1bbl', 'fuelsystem_2bbl', 'fuelsystem_4bbl',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 20))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
price_corr=data.corr()['price']

# %%
price_corr
# Out:
# symboling               -0.079978
# wheelbase                0.577816
# carlength                0.682920
# carwidth                 0.759325
# carheight                0.119336
# curbweight               0.835305
# enginesize               0.874145
# boreratio                0.553173
# stroke                   0.079443
# compressionratio         0.067984
# horsepower               0.808139
# peakrpm                 -0.085267
# citympg                 -0.685751
# highwaympg              -0.697599
# price                    1.000000
# fueltype_diesel          0.105679
# fueltype_gas            -0.105679
# aspiration_std          -0.177926
# aspiration_turbo         0.177926
# doornumber_four          0.031835
# doornumber_two          -0.031835
# carbody_convertible      0.187681
# carbody_hardtop          0.225854
# carbody_hatchback       -0.262039
# carbody_sedan            0.125716
# carbody_wagon           -0.042310
# drivewheel_4wd          -0.058866
# ...

# %%
columns=price_corr[(price_corr >0.2) | (price_corr < -0.2)].index

# %%
columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize',
#        'boreratio', 'horsepower', 'citympg', 'highwaympg', 'price',
#        'carbody_hardtop', 'carbody_hatchback', 'drivewheel_fwd',
#        'drivewheel_rwd', 'enginelocation_front', 'enginelocation_rear',
#        'enginetype_ohc', 'enginetype_ohcv', 'cylindernumber_eight',
#        'cylindernumber_five', 'cylindernumber_four', 'cylindernumber_six',
#        'fuelsystem_2bbl', 'fuelsystem_mpfi'],
#       dtype='object')

# %%
data2=data[columns]

# %%
data2.shape
# Out:
# (205, 24)

# %%
data2.corr()['price']
# Out:
# wheelbase               0.577816
# carlength               0.682920
# carwidth                0.759325
# curbweight              0.835305
# enginesize              0.874145
# boreratio               0.553173
# horsepower              0.808139
# citympg                -0.685751
# highwaympg             -0.697599
# price                   1.000000
# carbody_hardtop         0.225854
# carbody_hatchback      -0.262039
# drivewheel_fwd         -0.601950
# drivewheel_rwd          0.638957
# enginelocation_front   -0.324973
# enginelocation_rear     0.324973
# enginetype_ohc         -0.344270
# enginetype_ohcv         0.385991
# cylindernumber_eight    0.478614
# cylindernumber_five     0.249606
# cylindernumber_four    -0.697762
# cylindernumber_six      0.474978
# fuelsystem_2bbl        -0.501374
# fuelsystem_mpfi         0.517075
# Name: price, dtype: float64

# %%
data2
# Out:
#      wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0         88.6      168.8      64.1        2548         130       3.47
# 1         88.6      168.8      64.1        2548         130       3.47
# 2         94.5      171.2      65.5        2823         152       2.68
# 3         99.8      176.6      66.2        2337         109       3.19
# 4         99.4      176.6      66.4        2824         136       3.19
# ..         ...        ...       ...         ...         ...        ...
# 200      109.1      188.8      68.9        2952         141       3.78
# 201      109.1      188.8      68.8        3049         141       3.78
# 202      109.1      188.8      68.9        3012         173       3.58
# 203      109.1      188.8      68.9        3217         145       3.01
# 204      109.1      188.8      68.9        3062         141       3.78
#
#      horsepower  citympg  highwaympg    price  ...  enginelocation_front  \
# ...

# %%
data2.columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize',
#        'boreratio', 'horsepower', 'citympg', 'highwaympg', 'price',
#        'carbody_hardtop', 'carbody_hatchback', 'drivewheel_fwd',
#        'drivewheel_rwd', 'enginelocation_front', 'enginelocation_rear',
#        'enginetype_ohc', 'enginetype_ohcv', 'cylindernumber_eight',
#        'cylindernumber_five', 'cylindernumber_four', 'cylindernumber_six',
#        'fuelsystem_2bbl', 'fuelsystem_mpfi'],
#       dtype='object')

# %%
from sklearn.decomposition import PCA

carsize = data2[['carlength', 'carwidth']]
engine_loc = data2[['enginelocation_front', 'enginelocation_rear']]
engine_type = data2[['enginetype_ohc', 'enginetype_ohcv']]
drivewheel = data2[['drivewheel_fwd','drivewheel_rwd']]
cylinder = data2[['cylindernumber_eight','cylindernumber_five', 'cylindernumber_four', 'cylindernumber_six']]
carbody = data2[['carbody_hardtop', 'carbody_hatchback']]
fuelsystem = data2[['fuelsystem_2bbl', 'fuelsystem_mpfi']]


pca = PCA(n_components=1)
carsize = pca.fit_transform(carsize)
engine_loc = pca.fit_transform(engine_loc)
drivewheel = pca.fit_transform(drivewheel)
cylinder = pca.fit_transform(cylinder)
carbody = pca.fit_transform(carbody)
fuelsystem = pca.fit_transform(fuelsystem)

# Add PCA result to the original DataFrame
data2['Carsize'] = carsize
data2['engine_loc'] = engine_loc
data2['drivewheel'] = drivewheel
data2['cylinder'] = cylinder
data2['carbody'] = carbody
data2['fuelsystem'] = fuelsystem

data2.drop(['fuelsystem_2bbl', 'fuelsystem_mpfi','carbody_hardtop', 'carbody_hatchback','cylindernumber_eight','cylindernumber_five', 'cylindernumber_four', 'cylindernumber_six','carlength', 'carwidth','enginelocation_front', 'enginelocation_rear','enginetype_ohc', 'enginetype_ohcv','drivewheel_fwd','drivewheel_rwd','drivewheel_fwd','drivewheel_rwd'], axis=1,inplace=True)
# Out:
# <ipython-input-86-a6e7f1cec693>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Carsize'] = carsize
# <ipython-input-86-a6e7f1cec693>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['engine_loc'] = engine_loc
# <ipython-input-86-a6e7f1cec693>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data2
# Out:
#      wheelbase  curbweight  enginesize  boreratio  horsepower  citympg  \
# 0         88.6        2548         130       3.47         111       21
# 1         88.6        2548         130       3.47         111       21
# 2         94.5        2823         152       2.68         154       19
# 3         99.8        2337         109       3.19         102       24
# 4         99.4        2824         136       3.19         115       18
# ..         ...         ...         ...        ...         ...      ...
# 200      109.1        2952         141       3.78         114       23
# 201      109.1        3049         141       3.78         160       19
# 202      109.1        3012         173       3.58         134       18
# 203      109.1        3217         145       3.01         106       26
# 204      109.1        3062         141       3.78         114       19
#
#      highwaympg    price    Carsize  engine_loc  drivewheel  cylinder  \
# ...

# %%
data2.corr()['price']
# Out:
# wheelbase     0.577816
# curbweight    0.835305
# enginesize    0.874145
# boreratio     0.553173
# horsepower    0.808139
# citympg      -0.685751
# highwaympg   -0.697599
# price         1.000000
# Carsize       0.687500
# engine_loc    0.324973
# drivewheel    0.634173
# cylinder      0.683329
# carbody      -0.267336
# fuelsystem   -0.563643
# Name: price, dtype: float64

# %%
y=data2['price']
x=data2.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(x, y,
                                test_size=0.3,random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=3)

knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)

# %%
#n=3
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# RMSE 3878.3912102385334
# MAE 2299.608419354839

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error

print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("MAE",mean_absolute_error(y_test,y_pred))
#n=1
# Out:
# RMSE 4982.031258804955
# MAE 2615.685483870968

# %%
# as kclassifier chk the classes , kregressor chks mean value 
for K in range(20):
    K = K+1
    model = KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train, y_train)  #fit the model
    y_pred=model.predict(X_test)
    print('##############',K,'############')
    print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
    print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# ############## 1 ############
# RMSE 4982.031258804955
# MAE 2615.685483870968
# ############## 2 ############
# RMSE 4748.767360261629
# MAE 2547.5241935483873
# ############## 3 ############
# RMSE 3878.3912102385334
# MAE 2299.608419354839
# ############## 4 ############
# RMSE 3540.5549847556954
# MAE 2142.1922016129033
# ############## 5 ############
# RMSE 3651.66014907012
# MAE 2150.93064516129
# ############## 6 ############
# RMSE 3619.8576114090656
# MAE 2052.8315430107523
# ############## 7 ############
# RMSE 3455.153526009627
# MAE 2010.95737327189
# ############## 8 ############
# RMSE 3586.616712007034
# MAE 1983.9828649193548
# ############## 9 ############
# RMSE 3828.702011017356
# MAE 2054.7001200716845
# ############## 10 ############
# RMSE 4013.4244605729245
# MAE 2170.980914516129
# ############## 11 ############
# RMSE 4015.7345325349024
# MAE 2119.349951612903
# ############## 12 ############
# RMSE 4054.870078684865
# MAE 2096.2909959677418
# ...

# %%
x.columns
# Out:
# Index(['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower',
#        'citympg', 'highwaympg', 'Carsize', 'engine_loc', 'drivewheel',
#        'cylinder', 'carbody', 'fuelsystem'],
#       dtype='object')

# %%
a=int(input('enter car height:'))
b=int(input('enter car width:'))
carsize=PCA.fit_transfrom(a,b)
knn.predict(carsize)
# Out:
# enter car size23
